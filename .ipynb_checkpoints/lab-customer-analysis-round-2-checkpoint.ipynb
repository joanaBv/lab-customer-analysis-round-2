# %%
import pandas as pd

marketing_customer_analysis = pd.read_csv('C:/Users/joana/Ironhack/lab-customer-analysis-round-2/files_for_lab/csv_files/marketing_customer_analysis.csv')

column1_names = marketing_customer_analysis.columns
marketing_customer_analysis_df = pd.DataFrame(columns=column1_names)
marketing_customer_analysis_df = pd.concat([marketing_customer_analysis], axis=0)

# %%
# just checking

marketing_customer_analysis_df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
# getting rid of the excess index column

marketing_customer_analysis_df = marketing_customer_analysis_df.drop(['Unnamed: 0'], axis=1)

marketing_customer_analysis_df
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
# show the dataframe shape

print(marketing_customer_analysis_df.shape)
# Out:
# (10910, 25)

# %%
# first show the column headers we have

print(marketing_customer_analysis_df.columns)
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size', 'Vehicle Type'],
#       dtype='object')

# %%
# everything is in order except for the header "EmploymentStatus" which is missing a space

marketing_customer_analysis_df = marketing_customer_analysis_df.rename(columns={'EmploymentStatus':'Employment Status'})

# %%
# just checking

print(marketing_customer_analysis_df.columns)
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'Employment Status', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size', 'Vehicle Type'],
#       dtype='object')

# %%
# which columns are numerical

marketing_customer_analysis_df._get_numeric_data()
# Out:
#        Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
# which columns are categorical

marketing_customer_analysis_df.select_dtypes('object')
# Out:
#       Customer       State Response  Coverage Education Effective To Date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       Employment Status Gender Location Code Marital Status     Policy Type  \
# ...

# %%
# check how many nan values in each column

marketing_customer_analysis_df.isna().sum()
# Out:
# Customer                            0
# State                             631
# Customer Lifetime Value             0
# Response                          631
# Coverage                            0
# Education                           0
# Effective To Date                   0
# Employment Status                   0
# Gender                              0
# Income                              0
# Location Code                       0
# Marital Status                      0
# Monthly Premium Auto                0
# Months Since Last Claim           633
# Months Since Policy Inception       0
# Number of Open Complaints         633
# Number of Policies                  0
# Policy Type                         0
# Policy                              0
# Renew Offer Type                    0
# Sales Channel                       0
# Total Claim Amount                  0
# Vehicle Class                     622
# Vehicle Size                      622
# Vehicle Type                     5482
# ...

# %%
# we've got several null values in the following categories:

# State
# Response
# Months since last claim
# Number of open complaints
# Vehicle Class
# Vehicle Size
# Vehicle Type

# for State, Response, Vehicle Class, Size and Type I will use the mode to
# fill in the null values
# so I need to see the value dispersion for each category

# As for the remaining columns, Months since last claim and Number of open
# complaints, I will use the mean value to fill in the null values

# %%
# Start with "State"

marketing_customer_analysis_df['State'].value_counts(dropna=False)
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# NaN            631
# Name: State, dtype: int64

# %%
# For "State" the most common value is "California" by a considerable ammount,
# so I will use this answer to fill in the null values

marketing_customer_analysis_df['State'] = marketing_customer_analysis_df['State'].fillna('California')

# just checking

len(marketing_customer_analysis_df[marketing_customer_analysis_df['State'].isna()==True])
# Out:
# 0

# %%
# Same for "Response"

marketing_customer_analysis_df['Response'].value_counts(dropna=False)
# Out:
# No     8813
# Yes    1466
# NaN     631
# Name: Response, dtype: int64

# %%
marketing_customer_analysis_df['Response'] = marketing_customer_analysis_df['Response'].fillna('No')

# just checking

len(marketing_customer_analysis_df[marketing_customer_analysis_df['Response'].isna()==True])
# Out:
# 0

# %%
# Same for "Vehicle Class"

marketing_customer_analysis_df['Vehicle Class'].value_counts(dropna=False)
# Out:
# Four-Door Car    5212
# Two-Door Car     2118
# SUV              2012
# NaN               622
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: Vehicle Class, dtype: int64

# %%
marketing_customer_analysis_df['Vehicle Class'] = marketing_customer_analysis_df['Vehicle Class'].fillna('Four-Door Car')

# just checking

len(marketing_customer_analysis_df[marketing_customer_analysis_df['Vehicle Class'].isna()==True])
# Out:
# 0

# %%
# Same for "Vehicle Size"

marketing_customer_analysis_df['Vehicle Size'].value_counts(dropna=False)
# Out:
# Medsize    7251
# Small      1966
# Large      1071
# NaN         622
# Name: Vehicle Size, dtype: int64

# %%
marketing_customer_analysis_df['Vehicle Size'] = marketing_customer_analysis_df['Vehicle Size'].fillna('Medsize')

# just checking

len(marketing_customer_analysis_df[marketing_customer_analysis_df['Vehicle Size'].isna()==True])
# Out:
# 0

# %%
# Same for "Vehicle Type"

marketing_customer_analysis_df['Vehicle Type'].value_counts(dropna=False)
# Out:
# NaN    5482
# A      5428
# Name: Vehicle Type, dtype: int64

# %%
# Seing as there isn't a trend here and most of the values here are null,
# I have opted to remove this column alltogether

marketing_customer_analysis_df = marketing_customer_analysis_df.drop(['Vehicle Type'], axis=1)

# %%
# As for the remaining columns, Months since last claim and Number of open
# complaints, I will use the mean value to fill in the null values

import numpy as np

# first for "Months since last claim"

mean_months = marketing_customer_analysis_df['Months Since Last Claim'].mean()

marketing_customer_analysis_df['Months Since Last Claim'] = marketing_customer_analysis_df['Months Since Last Claim'].fillna(mean_months)

# then for "Number fo open complaints"

mean_complaints = marketing_customer_analysis_df['Number of Open Complaints'].mean()

marketing_customer_analysis_df['Number of Open Complaints'] = marketing_customer_analysis_df['Number of Open Complaints'].fillna(mean_complaints)

# just checking

print(len(marketing_customer_analysis_df[marketing_customer_analysis_df['Months Since Last Claim'].isna()==True]))

print(len(marketing_customer_analysis_df[marketing_customer_analysis_df['Number of Open Complaints'].isna()==True]))
# Out:
# 0
# 0

# %%
# Final Check

marketing_customer_analysis_df.isna().sum()
# Out:
# Customer                         0
# State                            0
# Customer Lifetime Value          0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# Employment Status                0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Renew Offer Type                 0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
# First I convert the "Effective to Date" column to the datetime format

import time
from datetime import date

marketing_customer_analysis_df['Effective To Date'] = pd.to_datetime(marketing_customer_analysis_df['Effective To Date'], errors='coerce')

#marketing['effective to date'] = pd.to_datetime(marketing['effective to date'], errors='coerce')
#marketing['month'] = marketing['effective to date'].dt.month


# Creating a new column to store a copy of the "Effective to Date" column

marketing_customer_analysis_df['Months'] = marketing_customer_analysis_df['Effective To Date'].dt.month

# filtering by first quarter

marketing_customer_analysis_df[(marketing_customer_analysis_df['Months']<=3)]
marketing_customer_analysis_df
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       Education Effective To Date Employment Status Gender  Income  ...  \
# ...
